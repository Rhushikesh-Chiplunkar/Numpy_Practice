# %%
import numpy as np 
arr = np.array([1,2,3,4,5])
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
result = arr * 2

# %%
result
# Out:
# array([ 2,  4,  6,  8, 10])

# %%
arr1 = np.array([[1,2,3,4],[5,6,7,8]])
arr2 = np.array([5,6,7,8])
result2 = arr1+arr2

# %%
result
result2
# Out:
# array([[ 6,  8, 10, 12],
#        [10, 12, 14, 16]])
