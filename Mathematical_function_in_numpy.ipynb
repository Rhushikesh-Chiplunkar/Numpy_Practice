# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5,6])

# %%
np.mean(arr)
# Out:
# 3.5

# %%
np.min(arr)
# Out:
# 1

# %%
np.max(arr)
# Out:
# 6

# %%
np.std(arr)
# Out:
# 1.707825127659933

# %%
np.sum(arr)
# Out:
# 21

# %%
np.percentile(arr, 50)
# Out:
# 3.5
